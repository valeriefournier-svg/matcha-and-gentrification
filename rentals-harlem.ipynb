# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("medianAskingRent_All.csv")
df
# Out:
#               areaName    Borough      areaType  2010-01  2010-02  2010-03  \
# 0              Astoria     Queens  neighborhood   1600.0   1650.0   1600.0
# 1           Auburndale     Queens  neighborhood   1585.0   1490.0   1490.0
# 2           Bath Beach   Brooklyn  neighborhood   1350.0   1350.0   1350.0
# 3    Battery Park City  Manhattan  neighborhood   3495.0   3250.0   3200.0
# 4            Bay Ridge   Brooklyn  neighborhood   1400.0   1400.0   1400.0
# ..                 ...        ...           ...      ...      ...      ...
# 177    Windsor Terrace   Brooklyn  neighborhood   1500.0   1600.0   1600.0
# 178          Woodhaven     Queens  neighborhood      NaN      NaN      NaN
# 179           Woodlawn      Bronx  neighborhood      NaN      NaN      NaN
# 180           Woodside     Queens  neighborhood   1700.0   1595.0   1200.0
# 181          Woodstock      Bronx  neighborhood      NaN   1500.0   1500.0
#
# ...

# %%
df= df[['areaName', '2019-06', '2020-06', '2021-06', '2022-06', '2023-06', '2024-06', '2025-06', '2026-06']]

# %%
df
# Out:
#               areaName  2019-06  2020-06  2021-06  2022-06  2023-06  2024-06  \
# 0              Astoria   2300.0   2275.0   2000.0   2650.0   2800.0   2980.0
# 1           Auburndale   1900.0   1995.0   2195.0   2514.0   2250.0   2700.0
# 2           Bath Beach   1750.0   1900.0   1799.0   1775.0   1850.0   2000.0
# 3    Battery Park City   5200.0   4950.0   4055.0   5250.0   5400.0   5435.0
# 4            Bay Ridge   1900.0   2000.0   1750.0   2300.0   2350.0   2400.0
# ..                 ...      ...      ...      ...      ...      ...      ...
# 177    Windsor Terrace   2850.0   2800.0   2400.0   3000.0   3395.0   3680.0
# 178          Woodhaven   1725.0   1773.0   1700.0   2000.0   2100.0   2800.0
# 179           Woodlawn   1750.0   1675.0   1599.0   2150.0      NaN   3300.0
# 180           Woodside   2000.0   2000.0   1857.0   2100.0   2725.0   2781.0
# 181          Woodstock   1800.0   1950.0   1800.0   1950.0   2550.0   2300.0
#
#      2025-06  2026-06
# ...

# %%
Harlem = df[df['areaName'].isin(['Central Harlem', 'West Harlem', 'East Harlem'])]

# %%
Harlem
# Out:
#            areaName  2019-06  2020-06  2021-06  2022-06  2023-06  2024-06  \
# 28   Central Harlem   2700.0   2650.0   2400.0   2995.0   3195.0   3200.0
# 53      East Harlem   2450.0   2430.0   2250.0   2700.0   3000.0   3000.0
# 171     West Harlem   2695.0   2600.0   2295.0   2800.0   3050.0   3500.0
#
#      2025-06  2026-06
# 28    3400.0   3600.0
# 53    3200.0   3250.0
# 171   3750.0   3800.0

# %%
Harlem.plot()
# Out:
# <Axes: >

# %%
Harlem.to_csv("HarlemRent.csv", index= False)
